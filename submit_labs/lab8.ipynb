# %% [markdown]
# ### Bài 1
#
# Nghiên cứu mức thu nhập ($X$) và chi tiêu ($Y$) trong một tháng của một công ty. Khảo sát ngẫu nhiên 7 nhân viên, ta thu được bảng số liệu sau:
#
# | X            | 130     | 150      | 133      | 170      | 170      | 210      | 230      |
# | :----------: | :-----: | :------: | :------: | :------: | :------: | :------: | :------: |
# | **Y**        | **84**  | **120**  | **108**  | **130**  | **130**  | **150**  | **160**  |
#
#
# a. Dựa vào bảng dữ liệu trên cho biết có xây dựng được mô hình hồi quy hay không? Nếu có hãy xây dựng mô hình hồi quy để ước tính chi tiêu dựa theo thu nhập
#
# b. Dự đoán mức chi tiêu của nhân viên công ty trên nếu biết thu nhập là 200$

# %%
#Gọi thư viện 
import numpy as np 
import matplotlib.pyplot as plt

# %%
#x
x = np.array([130,150,133,170,210,230])
#y
y = np.array([84,120,108,130,150,160])
plt.scatter(x, y)
plt.xlabel('X')
plt.ylabel('Y')
plt.show()
#từ mô hình phân tán trên ta có thê sử dụng mô hinh hồi quy tuyến tính

# %%
#khai báo và biểu diễn trên 1 một đồ thị hồi quy tuyến tính
plt.plot(x, y, 'o')
plt.axis([120, 240, 80, 170])
plt.xlabel('Mức thu nhập')
plt.ylabel('Chi tiêu')
plt.show()

# %%
tu = sum((x - x.mean()) * (y - y.mean()))
mau = sum((x - x.mean()) * (x - x.mean()))
b1 = tu/mau
b0 = y.mean() - b1 * x.mean()


print("Mức chi tiêu của nhân viên 200$: ",b1*200 + b0)
# Out:
# Mức chi tiêu của nhân viên 200$:  144.16099601206108

# %% [markdown]
# ### Bài 2
#
# Tiến hành nghiên cứu mối quan hệ giữa:
#
# - X: giá bán kẻ của thịt gà (nghìn/kg)
# - Y: lượng thịt gà tiêu thụ (kg/tháng)
#
# Dữ liệu thu được gồm 10 tháng như sau:
#
# | X            | 35       | 40       | 45       | 40       | 38       | 40       | 45       | 30       | 42       | 38       |
# | :----------: | :------: | :------: | :------: | :------: | :------: | :------: | :------: | :------: | :------: | :------: |
# | **Y**        | **2.29** | **2.04** | **0.59** | **2.06** | **2.50** | **2.32** | **1.57** | **3.96** | **1.43** | **2.34** |
#
#
# a. Dựa vào bảng dữ liệu trên cho biết có xây dựng được mô hình hồi quy hay không? Nếu có hãy xây dựng mô hình hồi quy để ước tính lượng tiêu thụ thịt gà theo giá bán.
#
# b. Dự đoán lượng tiêu thụ khi giá bán lẻ là 41(kg/tháng)

# %%
x = [35, 40, 45, 40, 38, 40, 45, 30, 42, 38]
y = [2.29, 2.04, 0.59, 2.06, 2.50, 2.32, 1.57, 3.96, 1.43, 2.34]

plt.scatter(x, y)
plt.xlabel('X')
plt.ylabel('Y')
plt.show()

#Từ biểu đồ phân tán, chúng ta có thể thấy rằng không 
# có mối quan hệ tuyến tính rõ ràng giữa X và Y. Do đó,
#  việc sử dụng mô hình hồi quy tuyến tính 
# để dự đoán giá trị Y dựa trên giá trị X 
# không phù hợp trong trường hợp này.

# %%
tu = sum((x - x.mean()) * (y - y.mean()))
mau = sum((x - x.mean()) * (x - x.mean()))
b1 = tu/mau
b0 = y.mean() - b1 * x.mean()

print("Lượng gà tiêu thụ khi giá gà bán lẻ là 41 nghìn/tháng : ",b0 + b1*41)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 tu = sum((x - x.mean()) * (y - y.mean()))
#       2 mau = sum((x - x.mean()) * (x - x.mean()))
#       3 b1 = tu/mau
#
# AttributeError: 'list' object has no attribute 'mean'
